# %% [markdown]
# <a href="https://colab.research.google.com/github/Suraj7687/Breast-Cancer/blob/main/Image_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# Specify the correct path to the image
image_path = 'image.jpg'
image = cv2.imread(image_path)

# Check if the image is loaded correctly
if image is None:
    raise ValueError(f"Image not found or unable to load: {image_path}")

# Resize the image to the desired dimensions
resized_image = cv2.resize(image, (224, 224))

# Optionally, display or print a confirmation
print("Image resized successfully.")
# Out:
# Image resized successfully.

# %%
normalized_image = resized_image / 255.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2]
)
augmented_image = datagen.random_transform(normalized_image)

# %%
from datetime import datetime
timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
location = 'Lat: 40.7128 N, Long: 74.0060 W'  # Example location (New York City)

# Simulate image capture
image = cv2.imread('image.jpg')  # Assuming an image is captured and saved as 'captured_image.jpg'

# %%
resized_image = cv2.resize(image, (224, 224))

# %%
normalized_image = resized_image / 255.0

# %%
augmented_image = datagen.random_transform(normalized_image)

# %% [markdown]
# **Displaying Resized Image**

# %%
import cv2
import matplotlib.pyplot as plt

# Specify the correct path to the image
image_path = 'image.jpg'
image = cv2.imread(image_path)

# Check if the image is loaded correctly
if image is None:
    raise ValueError(f"Image not found or unable to load: {image_path}")

# Resize the image to the desired dimensions
resized_image = cv2.resize(image, (224, 224))

# Convert the image from BGR to RGB
resized_image_rgb = cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB)

# Display the resized image using matplotlib
plt.imshow(resized_image_rgb)
plt.title('Resized Image')
plt.axis('off')  # Hide axis
plt.show()
